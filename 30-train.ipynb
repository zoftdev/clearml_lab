# %%
import clearml

from clearml import Task,Dataset

#load dataset

data= Dataset.get(dataset_id="68a52540085345c7b7f50ab47781e9b7")
local_path=data.get_local_copy()

print(local_path)
# Out:
# /Users/thisadee_pre/.clearml/cache/storage_manager/datasets/ds_68a52540085345c7b7f50ab47781e9b7

# %%
task=Task.init(project_name="titanic_demo", task_name="train the featurestore", reuse_last_task_id=False )
# Out:
# Jupyter Notebook auto-logging failed, could not access: /Users/thisadee_pre/play/clearml-lab/30-train-jvsc-6a929adf-4d2e-40fc-97a8-b3b092fe4f06516917a9-df35-49e3-8ecc-2334f0c8aac1.ipynb
# ClearML Task: created new task id=3d9fc0b7f9cb48d69716f69c11ba9ddf
# ClearML results page: https://app.clear.ml/projects/d4e8a8aa46b14e0797560c0895198091/experiments/3d9fc0b7f9cb48d69716f69c11ba9ddf/output/log

# %%
#list file in directory
import os
 
 
print(os.listdir(local_path))



import pandas as pd

train_df=pd.read_csv( f'{local_path}/train.csv')

print(train_df.head())
# Out:
# ['train.csv']
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      1
# 1      0          PC 17599  71.2833   C85        C      3
# 2      0  STON/O2. 3101282   7.9250   NaN        S      2
# 3      0            113803  53.1000  C123        S      3
# 4      0            373450   8.0500   NaN        S      1

# %%
def mytrain( train_df,**kwargs):
    print("training")
    return 0.8

# %%
fs_artifact=task.get_task(data.id).artifacts 
key_category_to_title=fs_artifact['key_category_to_title'].get()
print(key_category_to_title)
# Out:
# {'1': 'Mr', '2': 'Miss', '3': 'Mrs', '4': 'Master', '5': 'Rare'}

# %%
task.logger.report_table("debug","head", table_plot=train_df.head())

mytrain(train_df)
# Out:
# training
# 0.8

# %%
task.close()
# Out:
# ClearML Monitor: GPU monitoring failed getting GPU reading, switching off GPU monitoring
